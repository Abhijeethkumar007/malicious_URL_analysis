# %%
import pandas as pd
import itertools
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from lightgbm import LGBMClassifier
import os
import seaborn as sns
from wordcloud import WordCloud

# %%
df = pd.read_csv('malicious_phish.csv')

# %%
df
# Out:
#                                                       url        type
# 0                                        br-icloud.com.br    phishing
# 1                     mp3raid.com/music/krizz_kaliko.html      benign
# 2                         bopsecrets.org/rexroth/cr/1.htm      benign
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html    phishing
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    phishing
# 651188         www.gamespot.com/xbox360/action/deadspace/    phishing
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    phishing
# 651190          www.angelfire.com/goth/devilmaycrytonite/    phishing
#
# [651191 rows x 2 columns]

# %%
df_phish = df[df.type=='phishing']
df_malware = df[df.type=='malware']
df_deface = df[df.type=='defacement']
df_benign = df[df.type=='benign']

# %%
phish_url = " ".join(i for i in df_phish.url)
wordcloud = WordCloud(width=1600, height=800,colormap='Paired').generate(phish_url)
plt.figure( figsize=(12,14),facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
import re
#Use of IP or not in domain
def having_ip_address(url):
    match = re.search(
        '(([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\.'
        '([01]?\\d\\d?|2[0-4]\\d|25[0-5])\\/)|'  # IPv4
        '((0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\.(0x[0-9a-fA-F]{1,2})\\/)' # IPv4 in hexadecimal
        '(?:[a-fA-F0-9]{1,4}:){7}[a-fA-F0-9]{1,4}', url)  # Ipv6
    if match:
        # print match.group()
        return 1
    else:
        # print 'No matching pattern found'
        return 0
df['use_of_ip'] = df['url'].apply(lambda i: having_ip_address(i))

# %%
from urllib.parse import urlparse

def abnormal_url(url):
    hostname = urlparse(url).hostname
    hostname = str(hostname)
    match = re.search(hostname, url)
    if match:
        # print match.group()
        return 1
    else:
        # print 'No matching pattern found'
        return 0


df['abnormal_url'] = df['url'].apply(lambda i: abnormal_url(i))

# %%
from googlesearch import search

# %%
def google_index(url):
    site = search(url, 5)
    return 1 if site else 0
df['google_index'] = df['url'].apply(lambda i: google_index(i))

# %%
def count_dot(url):
    count_dot = url.count('.')
    return count_dot

df['count.'] = df['url'].apply(lambda i: count_dot(i))
df.head()
# Out:
#                                                  url        type  use_of_ip  \
# 0                                   br-icloud.com.br    phishing          0
# 1                mp3raid.com/music/krizz_kaliko.html      benign          0
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign          0
# 3  http://www.garage-pirenne.be/index.php?option=...  defacement          0
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement          0
#
#    abnormal_url  google_index  count.
# 0             0             1       2
# 1             0             1       2
# 2             0             1       2
# 3             1             1       3
# 4             1             1       2

# %%
def count_www(url):
    url.count('www')
    return url.count('www')

df['count-www'] = df['url'].apply(lambda i: count_www(i))

def count_atrate(url):
     
    return url.count('@')

df['count@'] = df['url'].apply(lambda i: count_atrate(i))


def no_of_dir(url):
    urldir = urlparse(url).path
    return urldir.count('/')

df['count_dir'] = df['url'].apply(lambda i: no_of_dir(i))

def no_of_embed(url):
    urldir = urlparse(url).path
    return urldir.count('//')

df['count_embed_domian'] = df['url'].apply(lambda i: no_of_embed(i))

# %%
def shortening_service(url):
    match = re.search('bit\.ly|goo\.gl|shorte\.st|go2l\.ink|x\.co|ow\.ly|t\.co|tinyurl|tr\.im|is\.gd|cli\.gs|'
                      'yfrog\.com|migre\.me|ff\.im|tiny\.cc|url4\.eu|twit\.ac|su\.pr|twurl\.nl|snipurl\.com|'
                      'short\.to|BudURL\.com|ping\.fm|post\.ly|Just\.as|bkite\.com|snipr\.com|fic\.kr|loopt\.us|'
                      'doiop\.com|short\.ie|kl\.am|wp\.me|rubyurl\.com|om\.ly|to\.ly|bit\.do|t\.co|lnkd\.in|'
                      'db\.tt|qr\.ae|adf\.ly|goo\.gl|bitly\.com|cur\.lv|tinyurl\.com|ow\.ly|bit\.ly|ity\.im|'
                      'q\.gs|is\.gd|po\.st|bc\.vc|twitthis\.com|u\.to|j\.mp|buzurl\.com|cutt\.us|u\.bb|yourls\.org|'
                      'x\.co|prettylinkpro\.com|scrnch\.me|filoops\.info|vzturl\.com|qr\.net|1url\.com|tweez\.me|v\.gd|'
                      'tr\.im|link\.zip\.net',
                      url)
    if match:
        return 1
    else:
        return 0
    
    
df['short_url'] = df['url'].apply(lambda i: shortening_service(i))

# %%
def count_https(url):
    return url.count('https')

df['count-https'] = df['url'].apply(lambda i : count_https(i))

def count_http(url):
    return url.count('http')

df['count-http'] = df['url'].apply(lambda i : count_http(i))

# %%
def count_per(url):
    return url.count('%')

df['count%'] = df['url'].apply(lambda i : count_per(i))

def count_ques(url):
    return url.count('?')

df['count?'] = df['url'].apply(lambda i: count_ques(i))

def count_hyphen(url):
    return url.count('-')

df['count-'] = df['url'].apply(lambda i: count_hyphen(i))

def count_equal(url):
    return url.count('=')

df['count='] = df['url'].apply(lambda i: count_equal(i))

def url_length(url):
    return len(str(url))

# %%
df['url_length'] = df['url'].apply(lambda i: url_length(i))
#Hostname Length

def hostname_length(url):
    return len(urlparse(url).netloc)

df['hostname_length'] = df['url'].apply(lambda i: hostname_length(i))


def suspicious_words(url):
    match = re.search('PayPal|login|signin|bank|account|update|free|lucky|service|bonus|ebayisapi|webscr',
                      url)
    if match:
        return 1
    else:
        return 0
df['sus_url'] = df['url'].apply(lambda i: suspicious_words(i))


def digit_count(url):
    digits = 0
    for i in url:
        if i.isnumeric():
            digits = digits + 1
    return digits


df['count-digits']= df['url'].apply(lambda i: digit_count(i))


def letter_count(url):
    letters = 0
    for i in url:
        if i.isalpha():
            letters = letters + 1
    return letters

df['count-letters']= df['url'].apply(lambda i: letter_count(i))

# %%
#Importing dependencies
from urllib.parse import urlparse
from tld import get_tld
import os.path

#First Directory Length
def fd_length(url):
    urlpath= urlparse(url).path
    try:
        return len(urlpath.split('/')[1])
    except:
        return 0

df['fd_length'] = df['url'].apply(lambda i: fd_length(i))

#Length of Top Level Domain
df['tld'] = df['url'].apply(lambda i: get_tld(i,fail_silently=True))


def tld_length(tld):
    try:
        return len(tld)
    except:
        return -1

df['tld_length'] = df['tld'].apply(lambda i: tld_length(i))

# %%
df
# Out:
#                                                       url        type  \
# 0                                        br-icloud.com.br    phishing
# 1                     mp3raid.com/music/krizz_kaliko.html      benign
# 2                         bopsecrets.org/rexroth/cr/1.htm      benign
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html    phishing
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    phishing
# 651188         www.gamespot.com/xbox360/action/deadspace/    phishing
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    phishing
# 651190          www.angelfire.com/goth/devilmaycrytonite/    phishing
#
#         use_of_ip  abnormal_url  google_index  count.  count-www  count@  \
# 0               0             0             1       2          0       0
# 1               0             0             1       2          0       0
# 2               0             0             1       2          0       0
# 3               0             1             1       3          1       0
# 4               0             1             1       2          0       0
# ...           ...           ...           ...     ...        ...     ...
# 651186          0             0             1       3          0       0
# 651187          0             0             1       2          0       0
# 651188          0             0             1       2          1       0
# 651189          0             0             1       2          0       0
# 651190          0             0             1       2          1       0
#
#         count_dir  count_embed_domian  ...  count-  count=  url_length  \
# 0               0                   0  ...       1       0          16
# 1               2                   0  ...       0       0          35
# 2               3                   0  ...       0       0          31
# 3               1                   0  ...       1       4          88
# 4               1                   0  ...       1       3         235
# ...           ...                 ...  ...     ...     ...         ...
# 651186          3                   0  ...       0       0          39
# 651187          4                   0  ...       2       0          44
# 651188          4                   0  ...       0       0          42
# 651189          2                   0  ...       0       0          45
# 651190          3                   0  ...       0       0          41
#
#         hostname_length  sus_url  count-digits  count-letters  fd_length  \
# 0                     0        0             0             13          0
# 1                     0        0             1             29          5
# 2                     0        0             1             25          7
# 3                    21        0             7             63          9
# 4                    23        0            22            199          9
# ...                 ...      ...           ...            ...        ...
# 651186                0        0            12             21          7
# 651187                0        0             7             29          8
# 651188                0        0             3             33          7
# 651189                0        0             0             36          4
# 651190                0        0             0             36          4
#
#          tld  tld_length
# 0       None          -1
# 1       None          -1
# 2       None          -1
# 3         be           2
# 4        net           3
# ...      ...         ...
# 651186  None          -1
# 651187  None          -1
# 651188  None          -1
# 651189  None          -1
# 651190  None          -1
#
# [651191 rows x 25 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
df["type_code"] = lb_make.fit_transform(df["type"])
df["type_code"].value_counts()
# Out:
# 0    428103
# 1     96457
# 3     94111
# 2     32520
# Name: type_code, dtype: int64

# %%
#Predictor Variables
# filtering out google_index as it has only 1 value
X = df[['use_of_ip','abnormal_url', 'count.', 'count-www', 'count@',
       'count_dir', 'count_embed_domian', 'short_url', 'count-https',
       'count-http', 'count%', 'count?', 'count-', 'count=', 'url_length',
       'hostname_length', 'sus_url', 'fd_length', 'tld_length', 'count-digits',
       'count-letters']]

#Target Variable
y = df['type_code']

# %%
df.columns
# Out:
# Index(['url', 'type', 'use_of_ip', 'abnormal_url', 'google_index', 'count.',
#        'count-www', 'count@', 'count_dir', 'count_embed_domian', 'short_url',
#        'count-https', 'count-http', 'count%', 'count?', 'count-', 'count=',
#        'url_length', 'hostname_length', 'sus_url', 'count-digits',
#        'count-letters', 'fd_length', 'tld', 'tld_length', 'type_code'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['url', 'type', 'use_of_ip', 'abnormal_url', 'google_index', 'count.',
#        'count-www', 'count@', 'count_dir', 'count_embed_domian', 'short_url',
#        'count-https', 'count-http', 'count%', 'count?', 'count-', 'count=',
#        'url_length', 'hostname_length', 'sus_url', 'count-digits',
#        'count-letters', 'fd_length', 'tld', 'tld_length', 'type_code'],
#       dtype='object')

# %%
#Predictor Variables
# filtering out google_index as it has only 1 value
X = df[['use_of_ip','abnormal_url', 'count.', 'count-www', 'count@',
       'count_dir', 'count_embed_domian', 'short_url', 'count-https',
       'count-http', 'count%', 'count?', 'count-', 'count=', 'url_length',
       'hostname_length', 'sus_url', 'fd_length', 'tld_length', 'count-digits',
       'count-letters']]

#Target Variable
y = df['type_code']

# %%
y
# Out:
# 0         3
# 1         0
# 2         0
# 3         1
# 4         1
#          ..
# 651186    3
# 651187    3
# 651188    3
# 651189    3
# 651190    3
# Name: type_code, Length: 651191, dtype: int32

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2,shuffle=True, random_state=5)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100,max_features='sqrt')
rf.fit(X_train,y_train)
y_pred_rf = rf.predict(X_test)
print(classification_report(y_test,y_pred_rf,target_names=['benign', 'defacement','phishing','malware']))

score = metrics.accuracy_score(y_test, y_pred_rf)
print("accuracy:   %0.3f" % score)

from sklearn import metrics
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.97      0.98      0.98     85621
#   defacement       0.98      0.99      0.99     19292
#     phishing       0.99      0.94      0.97      6504
#      malware       0.91      0.86      0.88     18822
#
#     accuracy                           0.97    130239
#    macro avg       0.96      0.95      0.95    130239
# weighted avg       0.97      0.97      0.97    130239
#
# accuracy:   0.966

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
from sklearn import metrics

xgb_c = xgb.XGBClassifier(n_estimators= 100)
xgb_c.fit(X_train,y_train)
y_pred_x = xgb_c.predict(X_test)
print(classification_report(y_test,y_pred_x,target_names=['benign', 'defacement','phishing','malware']))

score = metrics.accuracy_score(y_test, y_pred_x)
print("accuracy:   %0.3f" % score)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.97      0.99      0.98     85621
#   defacement       0.97      0.99      0.98     19292
#     phishing       0.98      0.91      0.94      6504
#      malware       0.91      0.83      0.87     18822
#
#     accuracy                           0.96    130239
#    macro avg       0.96      0.93      0.94    130239
# weighted avg       0.96      0.96      0.96    130239
#
# accuracy:   0.962

# %%
def main(url):
    
    status = []
    
    status.append(having_ip_address(url))
    status.append(abnormal_url(url))
    status.append(count_dot(url))
    status.append(count_www(url))
    status.append(count_atrate(url))
    status.append(no_of_dir(url))
    status.append(no_of_embed(url))
    
    status.append(shortening_service(url))
    status.append(count_https(url))
    status.append(count_http(url))
    
    status.append(count_per(url))
    status.append(count_ques(url))
    status.append(count_hyphen(url))
    status.append(count_equal(url))
    
    status.append(url_length(url))
    status.append(hostname_length(url))
    status.append(suspicious_words(url))
    status.append(digit_count(url))
    status.append(letter_count(url))
    status.append(fd_length(url))
    tld = get_tld(url,fail_silently=True)
      
    status.append(tld_length(tld))
    
    
    

    return status

# %%
def get_prediction_from_url(test_url):
    features_test = main(test_url)
    
    # Due to updates to scikit-learn, we now need a 2D array as a parameter to the predict function.
    features_test = np.array(features_test).reshape((1, -1))
    #print(features_test)

    pred = xgb_c.predict(features_test)
    if int(pred[0]) == 0:
        
        res="SAFE"
        return res
    elif int(pred[0]) == 1.0:
        
        res="DEFACEMENT"
        return res
    elif int(pred[0]) == 2.0:
        res="PHISHING"
        return res
        
    elif int(pred[0]) == 3.0:
        
        res="MALWARE"
        return res

# %%
xgb_c
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
import joblib
joblib.dump(xgb_c, 'xgb_finalmodel.pkl')
# Out:
# ['xgb_finalmodel.pkl']

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    min_child_weight=1,
    gamma=0,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='multi:softprob',
    n_jobs=-1,
    early_stopping_rounds=10
)

model.fit(X_train, y_train, eval_set=[(X, y)], verbose=True)
# Out:
# [0]	validation_0-mlogloss:1.30897
# [1]	validation_0-mlogloss:1.23639
# [2]	validation_0-mlogloss:1.17248
# [3]	validation_0-mlogloss:1.11235
# [4]	validation_0-mlogloss:1.05859
# [5]	validation_0-mlogloss:1.00854
# [6]	validation_0-mlogloss:0.96316
# [7]	validation_0-mlogloss:0.91963
# [8]	validation_0-mlogloss:0.88223
# [9]	validation_0-mlogloss:0.84458
# [10]	validation_0-mlogloss:0.81009
# [11]	validation_0-mlogloss:0.77881
# [12]	validation_0-mlogloss:0.74748
# [13]	validation_0-mlogloss:0.71911
# [14]	validation_0-mlogloss:0.69186
# [15]	validation_0-mlogloss:0.66789
# [16]	validation_0-mlogloss:0.64326
# [17]	validation_0-mlogloss:0.62018
# [18]	validation_0-mlogloss:0.59917
# [19]	validation_0-mlogloss:0.57890
# [20]	validation_0-mlogloss:0.55927
# [21]	validation_0-mlogloss:0.54107
# [22]	validation_0-mlogloss:0.52408
# [23]	validation_0-mlogloss:0.50814
# [24]	validation_0-mlogloss:0.49319
# [25]	validation_0-mlogloss:0.47924
# [26]	validation_0-mlogloss:0.46552
# [27]	validation_0-mlogloss:0.45247
# [28]	validation_0-mlogloss:0.44032
# [29]	validation_0-mlogloss:0.42914
# [30]	validation_0-mlogloss:0.41760
# [31]	validation_0-mlogloss:0.40693
# [32]	validation_0-mlogloss:0.39714
# [33]	validation_0-mlogloss:0.38769
# [34]	validation_0-mlogloss:0.37860
# [35]	validation_0-mlogloss:0.36966
# [36]	validation_0-mlogloss:0.36176
# [37]	validation_0-mlogloss:0.35397
# [38]	validation_0-mlogloss:0.34629
# [39]	validation_0-mlogloss:0.33905
# [40]	validation_0-mlogloss:0.33223
# [41]	validation_0-mlogloss:0.32567
# [42]	validation_0-mlogloss:0.31951
# [43]	validation_0-mlogloss:0.31356
# [44]	validation_0-mlogloss:0.30770
# [45]	validation_0-mlogloss:0.30232
# [46]	validation_0-mlogloss:0.29713
# [47]	validation_0-mlogloss:0.29221
# [48]	validation_0-mlogloss:0.28731
# [49]	validation_0-mlogloss:0.28293
# [50]	validation_0-mlogloss:0.27850
# [51]	validation_0-mlogloss:0.27441
# [52]	validation_0-mlogloss:0.27041
# [53]	validation_0-mlogloss:0.26657
# [54]	validation_0-mlogloss:0.26279
# [55]	validation_0-mlogloss:0.25921
# [56]	validation_0-mlogloss:0.25575
# [57]	validation_0-mlogloss:0.25238
# [58]	validation_0-mlogloss:0.24903
# [59]	validation_0-mlogloss:0.24602
# [60]	validation_0-mlogloss:0.24310
# [61]	validation_0-mlogloss:0.24030
# [62]	validation_0-mlogloss:0.23752
# [63]	validation_0-mlogloss:0.23489
# [64]	validation_0-mlogloss:0.23244
# [65]	validation_0-mlogloss:0.23009
# [66]	validation_0-mlogloss:0.22765
# [67]	validation_0-mlogloss:0.22558
# [68]	validation_0-mlogloss:0.22338
# [69]	validation_0-mlogloss:0.22136
# [70]	validation_0-mlogloss:0.21925
# [71]	validation_0-mlogloss:0.21738
# [72]	validation_0-mlogloss:0.21543
# [73]	validation_0-mlogloss:0.21367
# [74]	validation_0-mlogloss:0.21171
# [75]	validation_0-mlogloss:0.21008
# [76]	validation_0-mlogloss:0.20830
# [77]	validation_0-mlogloss:0.20676
# [78]	validation_0-mlogloss:0.20526
# [79]	validation_0-mlogloss:0.20387
# [80]	validation_0-mlogloss:0.20259
# [81]	validation_0-mlogloss:0.20117
# [82]	validation_0-mlogloss:0.19992
# [83]	validation_0-mlogloss:0.19864
# [84]	validation_0-mlogloss:0.19733
# [85]	validation_0-mlogloss:0.19611
# [86]	validation_0-mlogloss:0.19471
# [87]	validation_0-mlogloss:0.19342
# [88]	validation_0-mlogloss:0.19234
# [89]	validation_0-mlogloss:0.19108
# [90]	validation_0-mlogloss:0.19005
# [91]	validation_0-mlogloss:0.18893
# [92]	validation_0-mlogloss:0.18789
# [93]	validation_0-mlogloss:0.18677
# [94]	validation_0-mlogloss:0.18585
# [95]	validation_0-mlogloss:0.18498
# [96]	validation_0-mlogloss:0.18397
# [97]	validation_0-mlogloss:0.18313
# [98]	validation_0-mlogloss:0.18231
# [99]	validation_0-mlogloss:0.18131
# [100]	validation_0-mlogloss:0.18046
# [101]	validation_0-mlogloss:0.17963
# [102]	validation_0-mlogloss:0.17884
# [103]	validation_0-mlogloss:0.17804
# [104]	validation_0-mlogloss:0.17733
# [105]	validation_0-mlogloss:0.17666
# [106]	validation_0-mlogloss:0.17585
# [107]	validation_0-mlogloss:0.17525
# [108]	validation_0-mlogloss:0.17458
# [109]	validation_0-mlogloss:0.17393
# [110]	validation_0-mlogloss:0.17329
# [111]	validation_0-mlogloss:0.17268
# [112]	validation_0-mlogloss:0.17208
# [113]	validation_0-mlogloss:0.17138
# [114]	validation_0-mlogloss:0.17080
# [115]	validation_0-mlogloss:0.17016
# [116]	validation_0-mlogloss:0.16958
# [117]	validation_0-mlogloss:0.16900
# [118]	validation_0-mlogloss:0.16836
# [119]	validation_0-mlogloss:0.16785
# [120]	validation_0-mlogloss:0.16736
# [121]	validation_0-mlogloss:0.16674
# [122]	validation_0-mlogloss:0.16619
# [123]	validation_0-mlogloss:0.16577
# [124]	validation_0-mlogloss:0.16534
# [125]	validation_0-mlogloss:0.16487
# [126]	validation_0-mlogloss:0.16432
# [127]	validation_0-mlogloss:0.16395
# [128]	validation_0-mlogloss:0.16349
# [129]	validation_0-mlogloss:0.16311
# [130]	validation_0-mlogloss:0.16274
# [131]	validation_0-mlogloss:0.16232
# [132]	validation_0-mlogloss:0.16193
# [133]	validation_0-mlogloss:0.16152
# [134]	validation_0-mlogloss:0.16102
# [135]	validation_0-mlogloss:0.16063
# [136]	validation_0-mlogloss:0.16032
# [137]	validation_0-mlogloss:0.15996
# [138]	validation_0-mlogloss:0.15965
# [139]	validation_0-mlogloss:0.15932
# [140]	validation_0-mlogloss:0.15890
# [141]	validation_0-mlogloss:0.15853
# [142]	validation_0-mlogloss:0.15824
# [143]	validation_0-mlogloss:0.15787
# [144]	validation_0-mlogloss:0.15744
# [145]	validation_0-mlogloss:0.15716
# [146]	validation_0-mlogloss:0.15673
# [147]	validation_0-mlogloss:0.15640
# [148]	validation_0-mlogloss:0.15611
# [149]	validation_0-mlogloss:0.15577
# [150]	validation_0-mlogloss:0.15553
# [151]	validation_0-mlogloss:0.15519
# [152]	validation_0-mlogloss:0.15481
# [153]	validation_0-mlogloss:0.15454
# [154]	validation_0-mlogloss:0.15427
# [155]	validation_0-mlogloss:0.15390
# [156]	validation_0-mlogloss:0.15359
# [157]	validation_0-mlogloss:0.15334
# [158]	validation_0-mlogloss:0.15307
# [159]	validation_0-mlogloss:0.15282
# [160]	validation_0-mlogloss:0.15255
# [161]	validation_0-mlogloss:0.15227
# [162]	validation_0-mlogloss:0.15204
# [163]	validation_0-mlogloss:0.15171
# [164]	validation_0-mlogloss:0.15154
# [165]	validation_0-mlogloss:0.15126
# [166]	validation_0-mlogloss:0.15099
# [167]	validation_0-mlogloss:0.15067
# [168]	validation_0-mlogloss:0.15049
# [169]	validation_0-mlogloss:0.15024
# [170]	validation_0-mlogloss:0.15006
# [171]	validation_0-mlogloss:0.14983
# [172]	validation_0-mlogloss:0.14961
# [173]	validation_0-mlogloss:0.14938
# [174]	validation_0-mlogloss:0.14918
# [175]	validation_0-mlogloss:0.14895
# [176]	validation_0-mlogloss:0.14867
# [177]	validation_0-mlogloss:0.14849
# [178]	validation_0-mlogloss:0.14825
# [179]	validation_0-mlogloss:0.14799
# [180]	validation_0-mlogloss:0.14766
# [181]	validation_0-mlogloss:0.14748
# [182]	validation_0-mlogloss:0.14731
# [183]	validation_0-mlogloss:0.14704
# [184]	validation_0-mlogloss:0.14687
# [185]	validation_0-mlogloss:0.14664
# [186]	validation_0-mlogloss:0.14646
# [187]	validation_0-mlogloss:0.14631
# [188]	validation_0-mlogloss:0.14613
# [189]	validation_0-mlogloss:0.14589
# [190]	validation_0-mlogloss:0.14573
# [191]	validation_0-mlogloss:0.14548
# [192]	validation_0-mlogloss:0.14532
# [193]	validation_0-mlogloss:0.14503
# [194]	validation_0-mlogloss:0.14481
# [195]	validation_0-mlogloss:0.14466
# [196]	validation_0-mlogloss:0.14446
# [197]	validation_0-mlogloss:0.14433
# [198]	validation_0-mlogloss:0.14411
# [199]	validation_0-mlogloss:0.14397
# [200]	validation_0-mlogloss:0.14371
# [201]	validation_0-mlogloss:0.14358
# [202]	validation_0-mlogloss:0.14343
# [203]	validation_0-mlogloss:0.14321
# [204]	validation_0-mlogloss:0.14309
# [205]	validation_0-mlogloss:0.14290
# [206]	validation_0-mlogloss:0.14267
# [207]	validation_0-mlogloss:0.14249
# [208]	validation_0-mlogloss:0.14236
# [209]	validation_0-mlogloss:0.14225
# [210]	validation_0-mlogloss:0.14203
# [211]	validation_0-mlogloss:0.14192
# [212]	validation_0-mlogloss:0.14176
# [213]	validation_0-mlogloss:0.14152
# [214]	validation_0-mlogloss:0.14136
# [215]	validation_0-mlogloss:0.14115
# [216]	validation_0-mlogloss:0.14103
# [217]	validation_0-mlogloss:0.14092
# [218]	validation_0-mlogloss:0.14075
# [219]	validation_0-mlogloss:0.14053
# [220]	validation_0-mlogloss:0.14030
# [221]	validation_0-mlogloss:0.14011
# [222]	validation_0-mlogloss:0.13994
# [223]	validation_0-mlogloss:0.13972
# [224]	validation_0-mlogloss:0.13957
# [225]	validation_0-mlogloss:0.13936
# [226]	validation_0-mlogloss:0.13925
# [227]	validation_0-mlogloss:0.13914
# [228]	validation_0-mlogloss:0.13903
# [229]	validation_0-mlogloss:0.13886
# [230]	validation_0-mlogloss:0.13876
# [231]	validation_0-mlogloss:0.13869
# [232]	validation_0-mlogloss:0.13852
# [233]	validation_0-mlogloss:0.13840
# [234]	validation_0-mlogloss:0.13819
# [235]	validation_0-mlogloss:0.13809
# [236]	validation_0-mlogloss:0.13796
# [237]	validation_0-mlogloss:0.13773
# [238]	validation_0-mlogloss:0.13756
# [239]	validation_0-mlogloss:0.13746
# [240]	validation_0-mlogloss:0.13735
# [241]	validation_0-mlogloss:0.13717
# [242]	validation_0-mlogloss:0.13696
# [243]	validation_0-mlogloss:0.13681
# [244]	validation_0-mlogloss:0.13673
# [245]	validation_0-mlogloss:0.13656
# [246]	validation_0-mlogloss:0.13645
# [247]	validation_0-mlogloss:0.13629
# [248]	validation_0-mlogloss:0.13611
# [249]	validation_0-mlogloss:0.13601
# [250]	validation_0-mlogloss:0.13592
# [251]	validation_0-mlogloss:0.13574
# [252]	validation_0-mlogloss:0.13565
# [253]	validation_0-mlogloss:0.13549
# [254]	validation_0-mlogloss:0.13528
# [255]	validation_0-mlogloss:0.13519
# [256]	validation_0-mlogloss:0.13503
# [257]	validation_0-mlogloss:0.13491
# [258]	validation_0-mlogloss:0.13478
# [259]	validation_0-mlogloss:0.13465
# [260]	validation_0-mlogloss:0.13453
# [261]	validation_0-mlogloss:0.13443
# [262]	validation_0-mlogloss:0.13426
# [263]	validation_0-mlogloss:0.13408
# [264]	validation_0-mlogloss:0.13389
# [265]	validation_0-mlogloss:0.13376
# [266]	validation_0-mlogloss:0.13366
# [267]	validation_0-mlogloss:0.13354
# [268]	validation_0-mlogloss:0.13347
# [269]	validation_0-mlogloss:0.13339
# [270]	validation_0-mlogloss:0.13329
# [271]	validation_0-mlogloss:0.13315
# [272]	validation_0-mlogloss:0.13306
# [273]	validation_0-mlogloss:0.13295
# [274]	validation_0-mlogloss:0.13288
# [275]	validation_0-mlogloss:0.13274
# [276]	validation_0-mlogloss:0.13266
# [277]	validation_0-mlogloss:0.13252
# [278]	validation_0-mlogloss:0.13244
# [279]	validation_0-mlogloss:0.13228
# [280]	validation_0-mlogloss:0.13216
# [281]	validation_0-mlogloss:0.13205
# [282]	validation_0-mlogloss:0.13198
# [283]	validation_0-mlogloss:0.13189
# [284]	validation_0-mlogloss:0.13180
# [285]	validation_0-mlogloss:0.13174
# [286]	validation_0-mlogloss:0.13160
# [287]	validation_0-mlogloss:0.13144
# [288]	validation_0-mlogloss:0.13129
# [289]	validation_0-mlogloss:0.13111
# [290]	validation_0-mlogloss:0.13100
# [291]	validation_0-mlogloss:0.13091
# [292]	validation_0-mlogloss:0.13074
# [293]	validation_0-mlogloss:0.13066
# [294]	validation_0-mlogloss:0.13053
# [295]	validation_0-mlogloss:0.13043
# [296]	validation_0-mlogloss:0.13027
# [297]	validation_0-mlogloss:0.13017
# [298]	validation_0-mlogloss:0.12998
# [299]	validation_0-mlogloss:0.12990
# [300]	validation_0-mlogloss:0.12981
# [301]	validation_0-mlogloss:0.12970
# [302]	validation_0-mlogloss:0.12963
# [303]	validation_0-mlogloss:0.12949
# [304]	validation_0-mlogloss:0.12938
# [305]	validation_0-mlogloss:0.12928
# [306]	validation_0-mlogloss:0.12912
# [307]	validation_0-mlogloss:0.12899
# [308]	validation_0-mlogloss:0.12891
# [309]	validation_0-mlogloss:0.12881
# [310]	validation_0-mlogloss:0.12862
# [311]	validation_0-mlogloss:0.12854
# [312]	validation_0-mlogloss:0.12847
# [313]	validation_0-mlogloss:0.12833
# [314]	validation_0-mlogloss:0.12819
# [315]	validation_0-mlogloss:0.12814
# [316]	validation_0-mlogloss:0.12805
# [317]	validation_0-mlogloss:0.12794
# [318]	validation_0-mlogloss:0.12781
# [319]	validation_0-mlogloss:0.12771
# [320]	validation_0-mlogloss:0.12761
# [321]	validation_0-mlogloss:0.12750
# [322]	validation_0-mlogloss:0.12743
# [323]	validation_0-mlogloss:0.12734
# [324]	validation_0-mlogloss:0.12722
# [325]	validation_0-mlogloss:0.12716
# [326]	validation_0-mlogloss:0.12704
# [327]	validation_0-mlogloss:0.12695
# [328]	validation_0-mlogloss:0.12687
# [329]	validation_0-mlogloss:0.12679
# [330]	validation_0-mlogloss:0.12671
# [331]	validation_0-mlogloss:0.12662
# [332]	validation_0-mlogloss:0.12653
# [333]	validation_0-mlogloss:0.12647
# [334]	validation_0-mlogloss:0.12641
# [335]	validation_0-mlogloss:0.12635
# [336]	validation_0-mlogloss:0.12626
# [337]	validation_0-mlogloss:0.12619
# [338]	validation_0-mlogloss:0.12610
# [339]	validation_0-mlogloss:0.12603
# [340]	validation_0-mlogloss:0.12585
# [341]	validation_0-mlogloss:0.12576
# [342]	validation_0-mlogloss:0.12568
# [343]	validation_0-mlogloss:0.12559
# [344]	validation_0-mlogloss:0.12547
# [345]	validation_0-mlogloss:0.12539
# [346]	validation_0-mlogloss:0.12524
# [347]	validation_0-mlogloss:0.12511
# [348]	validation_0-mlogloss:0.12507
# [349]	validation_0-mlogloss:0.12497
# [350]	validation_0-mlogloss:0.12490
# [351]	validation_0-mlogloss:0.12476
# [352]	validation_0-mlogloss:0.12466
# [353]	validation_0-mlogloss:0.12456
# [354]	validation_0-mlogloss:0.12447
# [355]	validation_0-mlogloss:0.12441
# [356]	validation_0-mlogloss:0.12436
# [357]	validation_0-mlogloss:0.12430
# [358]	validation_0-mlogloss:0.12419
# [359]	validation_0-mlogloss:0.12411
# [360]	validation_0-mlogloss:0.12405
# [361]	validation_0-mlogloss:0.12399
# [362]	validation_0-mlogloss:0.12391
# [363]	validation_0-mlogloss:0.12386
# [364]	validation_0-mlogloss:0.12379
# [365]	validation_0-mlogloss:0.12370
# [366]	validation_0-mlogloss:0.12362
# [367]	validation_0-mlogloss:0.12354
# [368]	validation_0-mlogloss:0.12346
# [369]	validation_0-mlogloss:0.12338
# [370]	validation_0-mlogloss:0.12328
# [371]	validation_0-mlogloss:0.12322
# [372]	validation_0-mlogloss:0.12315
# [373]	validation_0-mlogloss:0.12308
# [374]	validation_0-mlogloss:0.12301
# [375]	validation_0-mlogloss:0.12295
# [376]	validation_0-mlogloss:0.12290
# [377]	validation_0-mlogloss:0.12283
# [378]	validation_0-mlogloss:0.12273
# [379]	validation_0-mlogloss:0.12262
# [380]	validation_0-mlogloss:0.12249
# [381]	validation_0-mlogloss:0.12236
# [382]	validation_0-mlogloss:0.12227
# [383]	validation_0-mlogloss:0.12216
# [384]	validation_0-mlogloss:0.12209
# [385]	validation_0-mlogloss:0.12198
# [386]	validation_0-mlogloss:0.12190
# [387]	validation_0-mlogloss:0.12176
# [388]	validation_0-mlogloss:0.12171
# [389]	validation_0-mlogloss:0.12165
# [390]	validation_0-mlogloss:0.12159
# [391]	validation_0-mlogloss:0.12152
# [392]	validation_0-mlogloss:0.12146
# [393]	validation_0-mlogloss:0.12141
# [394]	validation_0-mlogloss:0.12134
# [395]	validation_0-mlogloss:0.12129
# [396]	validation_0-mlogloss:0.12122
# [397]	validation_0-mlogloss:0.12117
# [398]	validation_0-mlogloss:0.12112
# [399]	validation_0-mlogloss:0.12106
# [400]	validation_0-mlogloss:0.12101
# [401]	validation_0-mlogloss:0.12095
# [402]	validation_0-mlogloss:0.12086
# [403]	validation_0-mlogloss:0.12077
# [404]	validation_0-mlogloss:0.12069
# [405]	validation_0-mlogloss:0.12059
# [406]	validation_0-mlogloss:0.12053
# [407]	validation_0-mlogloss:0.12045
# [408]	validation_0-mlogloss:0.12036
# [409]	validation_0-mlogloss:0.12031
# [410]	validation_0-mlogloss:0.12022
# [411]	validation_0-mlogloss:0.12016
# [412]	validation_0-mlogloss:0.12008
# [413]	validation_0-mlogloss:0.12004
# [414]	validation_0-mlogloss:0.11998
# [415]	validation_0-mlogloss:0.11990
# [416]	validation_0-mlogloss:0.11985
# [417]	validation_0-mlogloss:0.11979
# [418]	validation_0-mlogloss:0.11972
# [419]	validation_0-mlogloss:0.11966
# [420]	validation_0-mlogloss:0.11958
# [421]	validation_0-mlogloss:0.11948
# [422]	validation_0-mlogloss:0.11942
# [423]	validation_0-mlogloss:0.11934
# [424]	validation_0-mlogloss:0.11926
# [425]	validation_0-mlogloss:0.11921
# [426]	validation_0-mlogloss:0.11915
# [427]	validation_0-mlogloss:0.11908
# [428]	validation_0-mlogloss:0.11905
# [429]	validation_0-mlogloss:0.11899
# [430]	validation_0-mlogloss:0.11890
# [431]	validation_0-mlogloss:0.11884
# [432]	validation_0-mlogloss:0.11879
# [433]	validation_0-mlogloss:0.11872
# [434]	validation_0-mlogloss:0.11864
# [435]	validation_0-mlogloss:0.11857
# [436]	validation_0-mlogloss:0.11851
# [437]	validation_0-mlogloss:0.11844
# [438]	validation_0-mlogloss:0.11833
# [439]	validation_0-mlogloss:0.11823
# [440]	validation_0-mlogloss:0.11819
# [441]	validation_0-mlogloss:0.11814
# [442]	validation_0-mlogloss:0.11807
# [443]	validation_0-mlogloss:0.11802
# [444]	validation_0-mlogloss:0.11795
# [445]	validation_0-mlogloss:0.11786
# [446]	validation_0-mlogloss:0.11781
# [447]	validation_0-mlogloss:0.11773
# [448]	validation_0-mlogloss:0.11770
# [449]	validation_0-mlogloss:0.11768
# [450]	validation_0-mlogloss:0.11763
# [451]	validation_0-mlogloss:0.11758
# [452]	validation_0-mlogloss:0.11754
# [453]	validation_0-mlogloss:0.11750
# [454]	validation_0-mlogloss:0.11741
# [455]	validation_0-mlogloss:0.11735
# [456]	validation_0-mlogloss:0.11729
# [457]	validation_0-mlogloss:0.11721
# [458]	validation_0-mlogloss:0.11711
# [459]	validation_0-mlogloss:0.11707
# [460]	validation_0-mlogloss:0.11703
# [461]	validation_0-mlogloss:0.11698
# [462]	validation_0-mlogloss:0.11689
# [463]	validation_0-mlogloss:0.11684
# [464]	validation_0-mlogloss:0.11678
# [465]	validation_0-mlogloss:0.11672
# [466]	validation_0-mlogloss:0.11667
# [467]	validation_0-mlogloss:0.11659
# [468]	validation_0-mlogloss:0.11647
# [469]	validation_0-mlogloss:0.11639
# [470]	validation_0-mlogloss:0.11633
# [471]	validation_0-mlogloss:0.11629
# [472]	validation_0-mlogloss:0.11624
# [473]	validation_0-mlogloss:0.11619
# [474]	validation_0-mlogloss:0.11615
# [475]	validation_0-mlogloss:0.11609
# [476]	validation_0-mlogloss:0.11601
# [477]	validation_0-mlogloss:0.11597
# [478]	validation_0-mlogloss:0.11594
# [479]	validation_0-mlogloss:0.11589
# [480]	validation_0-mlogloss:0.11583
# [481]	validation_0-mlogloss:0.11578
# [482]	validation_0-mlogloss:0.11573
# [483]	validation_0-mlogloss:0.11571
# [484]	validation_0-mlogloss:0.11562
# [485]	validation_0-mlogloss:0.11557
# [486]	validation_0-mlogloss:0.11552
# [487]	validation_0-mlogloss:0.11545
# [488]	validation_0-mlogloss:0.11540
# [489]	validation_0-mlogloss:0.11535
# [490]	validation_0-mlogloss:0.11528
# [491]	validation_0-mlogloss:0.11520
# [492]	validation_0-mlogloss:0.11517
# [493]	validation_0-mlogloss:0.11512
# [494]	validation_0-mlogloss:0.11506
# [495]	validation_0-mlogloss:0.11502
# [496]	validation_0-mlogloss:0.11496
# [497]	validation_0-mlogloss:0.11488
# [498]	validation_0-mlogloss:0.11484
# [499]	validation_0-mlogloss:0.11480
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=-1,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=-1,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xgb_c = model.XGBClassifier(n_estimators= 100)
xgb_c.fit(X_train,y_train)
y_pred_x = xgb_c.predict(X_test)
print(classification_report(y_test,y_pred_x,target_names=['benign', 'defacement','phishing','malware']))
score = metrics.accuracy_score(y_test, y_pred_x)
print("accuracy:   %0.3f" % score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 xgb_c = model.XGBClassifier(n_estimators= 100)
#       2 xgb_c.fit(X_train,y_train)
#       3 y_pred_x = xgb_c.predict(X_test)
#
# AttributeError: 'XGBClassifier' object has no attribute 'XGBClassifier'

# %%
urls = ['titaniumcorporate.co.za','en.wikipedia.org/wiki/North_Dakota']
for url in urls:
     print(get_prediction_from_url(url))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 urls = ['titaniumcorporate.co.za','en.wikipedia.org/wiki/North_Dakota']
#       2 for url in urls:
# ----> 3      print(get_prediction_from_url(url))
#
# Cell In[38], line 2, in get_prediction_from_url(test_url)
#       1 def get_prediction_from_url(test_url):
# ----> 2     features_test = main(test_url)
#       4     # Due to updates to scikit-learn, we now need a 2D array as a parameter to the predict function.
#       5     features_test = np.array(features_test).reshape((1, -1))
#
# NameError: name 'main' is not defined
